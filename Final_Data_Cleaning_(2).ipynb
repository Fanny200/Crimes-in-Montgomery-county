# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('Crime_Dataset_Coursework1.csv')
# Out:
# C:\Users\Samruddhi\AppData\Local\Temp\ipykernel_22400\3592788205.py:1: DtypeWarning: Columns (1,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('Crime_Dataset_Coursework1.csv')

# %%
df1
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Street Prefix     Street Name Street Suffix  Street Type  \
# 0                NaN     MIDDLEBROOK           NaN           RD
# 1                NaN        WOODMONT           NaN          AVE
# 2                NaN        WOODMONT           NaN          AVE
# 3                NaN  QUINCE ORCHARD           NaN           RD
# 4                NaN        FALSTONE           NaN          AVE
# ...              ...             ...           ...          ...
# 306089           NaN       TRANSHIRE           NaN           RD
# 306090           NaN        ATHERTON           NaN           DR
# 306091           NaN       BALTUSROL           NaN           DR
# 306092           NaN          FENTON           NaN           ST
# 306093           NaN    NEWPORT MILL           NaN           RD
#
#                Start_Date_Time           End_Date_Time   Latitude  Longitude  \
# 0       08/23/2018 09:52:00 PM                     NaN  39.177744 -77.265619
# 1       03/30/2018 01:01:00 AM                     NaN  38.992693 -77.097063
# 2       03/30/2018 01:01:00 AM                     NaN  38.992693 -77.097063
# 3       06/14/2018 10:26:00 PM  06/15/2018 03:00:00 AM  39.147954 -77.218189
# 4       09/02/2018 11:30:00 PM  09/03/2018 12:30:00 AM  38.966174 -77.096561
# ...                        ...                     ...        ...        ...
# 306089  02/20/2021 08:00:00 PM                     NaN  39.172701 -77.197340
# 306090  05/06/2021 03:15:00 AM                     NaN  39.059672 -77.075995
# 306091  05/05/2021 10:38:00 PM                     NaN  39.199722 -77.273039
# 306092  03/13/2021 01:35:00 PM                     NaN  38.985813 -77.022915
# 306093  04/18/2021 04:00:00 PM  04/19/2021 12:00:00 PM  39.037115 -77.072485
#
#        Police District Number             Location
# 0                          5D  (39.1777, -77.2656)
# 1                          2D  (38.9927, -77.0971)
# 2                          2D  (38.9927, -77.0971)
# 3                          6D   (39.148, -77.2182)
# 4                          2D  (38.9662, -77.0966)
# ...                       ...                  ...
# 306089                     6D  (39.1727, -77.1973)
# 306090                     4D   (39.0597, -77.076)
# 306091                     5D   (39.1997, -77.273)
# 306092                     3D  (38.9858, -77.0229)
# 306093                     2D  (39.0371, -77.0725)
#
# [306094 rows x 30 columns]

# %%
df1.shape
# Out:
# (306094, 30)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306094 entries, 0 to 306093
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident ID             306094 non-null  int64
#  1   Offence Code            306094 non-null  object
#  2   CR Number               306094 non-null  int64
#  3   Dispatch Date / Time    257065 non-null  object
#  4   NIBRS Code              306094 non-null  object
#  5   Victims                 306094 non-null  int64
#  6   Crime Name1             305822 non-null  object
#  7   Crime Name2             305822 non-null  object
#  8   Crime Name3             305822 non-null  object
#  9   Police District Name    306000 non-null  object
#  10  Block Address           279888 non-null  object
#  11  City                    304818 non-null  object
#  12  State                   306094 non-null  object
#  13  Zip Code                302915 non-null  float64
#  14  Agency                  306094 non-null  object
#  15  Place                   306094 non-null  object
#  16  Sector                  304564 non-null  object
#  17  Beat                    304564 non-null  object
#  18  PRA                     305855 non-null  object
#  19  Address Number          279985 non-null  float64
#  20  Street Prefix           13631 non-null   object
#  21  Street Name             306093 non-null  object
#  22  Street Suffix           5432 non-null    object
#  23  Street Type             305755 non-null  object
#  24  Start_Date_Time         306094 non-null  object
#  25  End_Date_Time           144436 non-null  object
#  26  Latitude                306094 non-null  float64
#  27  Longitude               306094 non-null  float64
#  28  Police District Number  306094 non-null  object
#  29  Location                306094 non-null  object
# dtypes: float64(4), int64(3), object(23)
# memory usage: 70.1+ MB

# %%
df1.dtypes
# Out:
# Incident ID                 int64
# Offence Code               object
# CR Number                   int64
# Dispatch Date / Time       object
# NIBRS Code                 object
# Victims                     int64
# Crime Name1                object
# Crime Name2                object
# Crime Name3                object
# Police District Name       object
# Block Address              object
# City                       object
# State                      object
# Zip Code                  float64
# Agency                     object
# Place                      object
# Sector                     object
# Beat                       object
# PRA                        object
# Address Number            float64
# Street Prefix              object
# Street Name                object
# Street Suffix              object
# Street Type                object
# Start_Date_Time            object
# End_Date_Time              object
# Latitude                  float64
# Longitude                 float64
# Police District Number     object
# Location                   object
# dtype: object

# %%
null_rows = df1.isnull().sum()

# %%
null_rows
# Out:
# Incident ID                    0
# Offence Code                   0
# CR Number                      0
# Dispatch Date / Time       49029
# NIBRS Code                     0
# Victims                        0
# Crime Name1                  272
# Crime Name2                  272
# Crime Name3                  272
# Police District Name          94
# Block Address              26206
# City                        1276
# State                          0
# Zip Code                    3179
# Agency                         0
# Place                          0
# Sector                      1530
# Beat                        1530
# PRA                          239
# Address Number             26109
# Street Prefix             292463
# Street Name                    1
# Street Suffix             300662
# Street Type                  339
# Start_Date_Time                0
# End_Date_Time             161658
# Latitude                       0
# Longitude                      0
# Police District Number         0
# Location                       0
# dtype: int64

# %% [markdown]
# ### Dropping the columns

# %% [markdown]
# #### Dropping columns street prefix ( null values = 2,92,463 which is approx around 3lakhs) and street suffix(null values = 3,00,662 which is approx around 3lakhss)-Because of the large sets of null values dropping the columns

# %% [markdown]
# #### Dropping column Zip Code, Agency, End Date/time, Sector, Beat, PRA, Address Number,Location from the dataset because they do not contribute to the analysis objectives.This will help streamline our data and focus on the relevant features.

# %%
drop_Col = ['Zip Code','Agency','End_Date_Time','Street Prefix','Street Suffix','Sector','Beat','PRA','Address Number','Location']
df1 = df1.drop(columns = drop_Col)

# %%
df1
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA
# ...                                            ...                  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE
# 306090                         LARCENY - FROM AUTO              WHEATON
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN
# 306092                          ALL OTHER OFFENSES        SILVER SPRING
# 306093                         LARCENY - FROM AUTO             BETHESDA
#
#                      Block Address                City State  \
# 0        12800 BLK  MIDDLEBROOK RD          GERMANTOWN    MD
# 1           8300 BLK  WOODMONT AVE            BETHESDA    MD
# 2           8300 BLK  WOODMONT AVE            BETHESDA    MD
# 3       400 BLK  QUINCE ORCHARD RD        GAITHERSBURG    MD
# 4           4800 BLK  FALSTONE AVE         CHEVY CHASE    MD
# ...                            ...                 ...   ...
# 306089     19300 BLK  TRANSHIRE RD  MONTGOMERY VILLAGE    MD
# 306090      12500 BLK  ATHERTON DR       SILVER SPRING    MD
# 306091       300 BLK  BALTUSROL DR          GERMANTOWN    MD
# 306092         7700 BLK  FENTON ST       SILVER SPRING    MD
# 306093  11100 BLK  NEWPORT MILL RD          KENSINGTON    MD
#
#                               Place     Street Name Street Type  \
# 0               Street - In vehicle     MIDDLEBROOK          RD
# 1               Street - In vehicle        WOODMONT         AVE
# 2               Street - In vehicle        WOODMONT         AVE
# 3                  Hotel/Motel/Etc.  QUINCE ORCHARD          RD
# 4         Residence - Single Family        FALSTONE         AVE
# ...                             ...             ...         ...
# 306089  Residence -Townhouse/Duplex       TRANSHIRE          RD
# 306090    Parking Lot - Residential        ATHERTON          DR
# 306091  Residence - Apartment/Condo       BALTUSROL          DR
# 306092               Street - Other          FENTON          ST
# 306093         Street - Residential    NEWPORT MILL          RD
#
#                Start_Date_Time   Latitude  Longitude Police District Number
# 0       08/23/2018 09:52:00 PM  39.177744 -77.265619                     5D
# 1       03/30/2018 01:01:00 AM  38.992693 -77.097063                     2D
# 2       03/30/2018 01:01:00 AM  38.992693 -77.097063                     2D
# 3       06/14/2018 10:26:00 PM  39.147954 -77.218189                     6D
# 4       09/02/2018 11:30:00 PM  38.966174 -77.096561                     2D
# ...                        ...        ...        ...                    ...
# 306089  02/20/2021 08:00:00 PM  39.172701 -77.197340                     6D
# 306090  05/06/2021 03:15:00 AM  39.059672 -77.075995                     4D
# 306091  05/05/2021 10:38:00 PM  39.199722 -77.273039                     5D
# 306092  03/13/2021 01:35:00 PM  38.985813 -77.022915                     3D
# 306093  04/18/2021 04:00:00 PM  39.037115 -77.072485                     2D
#
# [306094 rows x 20 columns]

# %% [markdown]
# ### Replacing the Null Values

# %% [markdown]
# #### Replacing null values in columns - Crime Name1,Crime Name2, Crime Name3,Police District Name,Block Address,City,Street Name as Unknown

# %%
null_Values_col = ['Crime Name1','Crime Name2','Crime Name3','Police District Name','Block Address','City','Street Name','Street Type']

# %%
df1[null_Values_col]= df1[null_Values_col].fillna('Unknown')

# %% [markdown]
# #### Assuming that Start Date/time and Dispatch Date/time are same, Replace the null values as same as start Date/time.

# %%
df1['Dispatch Date / Time'] = df1['Dispatch Date / Time'].fillna('df1[Start_Date_Time]')

# %% [markdown]
# ##### Checking the null values

# %%
df1.isnull().sum()
# Out:
# Incident ID               0
# Offence Code              0
# CR Number                 0
# Dispatch Date / Time      0
# NIBRS Code                0
# Victims                   0
# Crime Name1               0
# Crime Name2               0
# Crime Name3               0
# Police District Name      0
# Block Address             0
# City                      0
# State                     0
# Place                     0
# Street Name               0
# Street Type               0
# Start_Date_Time           0
# Latitude                  0
# Longitude                 0
# Police District Number    0
# dtype: int64

# %% [markdown]
# ### Data Cleaning and Transformation

# %% [markdown]
# #### Separating the Date/time column

# %%
df1['Dispatch Date'] = df1['Dispatch Date / Time'].str.split(' ').str[0]
df1['Dispatch Time'] = df1['Dispatch Date / Time'].str.split(' ').str[1]
df1['Start Date'] = df1['Start_Date_Time'].str.split(' ').str[0]
df1['Start Time'] = df1['Start_Date_Time'].str.split(' ').str[1]

# %%
df1
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#            Street Name Street Type         Start_Date_Time   Latitude  \
# 0          MIDDLEBROOK          RD  08/23/2018 09:52:00 PM  39.177744
# 1             WOODMONT         AVE  03/30/2018 01:01:00 AM  38.992693
# 2             WOODMONT         AVE  03/30/2018 01:01:00 AM  38.992693
# 3       QUINCE ORCHARD          RD  06/14/2018 10:26:00 PM  39.147954
# 4             FALSTONE         AVE  09/02/2018 11:30:00 PM  38.966174
# ...                ...         ...                     ...        ...
# 306089       TRANSHIRE          RD  02/20/2021 08:00:00 PM  39.172701
# 306090        ATHERTON          DR  05/06/2021 03:15:00 AM  39.059672
# 306091       BALTUSROL          DR  05/05/2021 10:38:00 PM  39.199722
# 306092          FENTON          ST  03/13/2021 01:35:00 PM  38.985813
# 306093    NEWPORT MILL          RD  04/18/2021 04:00:00 PM  39.037115
#
#         Longitude Police District Number Dispatch Date  Dispatch Time  \
# 0      -77.265619                     5D    08/23/2018       09:52:08
# 1      -77.097063                     2D    03/30/2018       01:00:55
# 2      -77.097063                     2D    03/30/2018       01:00:55
# 3      -77.218189                     6D    06/14/2018       10:26:45
# 4      -77.096561                     2D    09/03/2018       12:06:54
# ...           ...                    ...           ...            ...
# 306089 -77.197340                     6D    02/21/2021       07:25:28
# 306090 -77.075995                     4D    05/06/2021       10:54:47
# 306091 -77.273039                     5D    05/05/2021       10:38:58
# 306092 -77.022915                     3D    03/13/2021       12:07:14
# 306093 -77.072485                     2D    04/19/2021       02:17:29
#
#         Start Date Start Time
# 0       08/23/2018   09:52:00
# 1       03/30/2018   01:01:00
# 2       03/30/2018   01:01:00
# 3       06/14/2018   10:26:00
# 4       09/02/2018   11:30:00
# ...            ...        ...
# 306089  02/20/2021   08:00:00
# 306090  05/06/2021   03:15:00
# 306091  05/05/2021   10:38:00
# 306092  03/13/2021   01:35:00
# 306093  04/18/2021   04:00:00
#
# [306094 rows x 24 columns]

# %% [markdown]
# #### Converting Start Date column to Datetime format to extract Day,Month,Year and Day of week

# %%
df1['Start Date'] = pd.to_datetime(df1['Start Date'], errors='coerce')

# %%
df1['day'] = df1['Start Date'].dt.day
df1['month'] = df1['Start Date'].dt.month
df1['year'] = df1['Start Date'].dt.year

# %%
df1['Day_of_Week'] = df1['Start Date'].dt.day_name()

# %%
df1
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#         Longitude Police District Number Dispatch Date Dispatch Time  \
# 0      -77.265619                     5D    08/23/2018      09:52:08
# 1      -77.097063                     2D    03/30/2018      01:00:55
# 2      -77.097063                     2D    03/30/2018      01:00:55
# 3      -77.218189                     6D    06/14/2018      10:26:45
# 4      -77.096561                     2D    09/03/2018      12:06:54
# ...           ...                    ...           ...           ...
# 306089 -77.197340                     6D    02/21/2021      07:25:28
# 306090 -77.075995                     4D    05/06/2021      10:54:47
# 306091 -77.273039                     5D    05/05/2021      10:38:58
# 306092 -77.022915                     3D    03/13/2021      12:07:14
# 306093 -77.072485                     2D    04/19/2021      02:17:29
#
#        Start Date Start Time day  month  year Day_of_Week
# 0      2018-08-23   09:52:00  23      8  2018    Thursday
# 1      2018-03-30   01:01:00  30      3  2018      Friday
# 2      2018-03-30   01:01:00  30      3  2018      Friday
# 3      2018-06-14   10:26:00  14      6  2018    Thursday
# 4      2018-09-02   11:30:00   2      9  2018      Sunday
# ...           ...        ...  ..    ...   ...         ...
# 306089 2021-02-20   08:00:00  20      2  2021    Saturday
# 306090 2021-05-06   03:15:00   6      5  2021    Thursday
# 306091 2021-05-05   10:38:00   5      5  2021   Wednesday
# 306092 2021-03-13   01:35:00  13      3  2021    Saturday
# 306093 2021-04-18   04:00:00  18      4  2021      Sunday
#
# [306094 rows x 28 columns]

# %% [markdown]
# #### Extracting Seasons from month column

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# %%
df1['Season'] = df1['month'].apply(get_season)

# %%
df1
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Police District Number Dispatch Date Dispatch Time Start Date  \
# 0                          5D    08/23/2018      09:52:08 2018-08-23
# 1                          2D    03/30/2018      01:00:55 2018-03-30
# 2                          2D    03/30/2018      01:00:55 2018-03-30
# 3                          6D    06/14/2018      10:26:45 2018-06-14
# 4                          2D    09/03/2018      12:06:54 2018-09-02
# ...                       ...           ...           ...        ...
# 306089                     6D    02/21/2021      07:25:28 2021-02-20
# 306090                     4D    05/06/2021      10:54:47 2021-05-06
# 306091                     5D    05/05/2021      10:38:58 2021-05-05
# 306092                     3D    03/13/2021      12:07:14 2021-03-13
# 306093                     2D    04/19/2021      02:17:29 2021-04-18
#
#        Start Time day month  year  Day_of_Week  Season
# 0        09:52:00  23     8  2018     Thursday  Summer
# 1        01:01:00  30     3  2018       Friday  Spring
# 2        01:01:00  30     3  2018       Friday  Spring
# 3        10:26:00  14     6  2018     Thursday  Summer
# 4        11:30:00   2     9  2018       Sunday    Fall
# ...           ...  ..   ...   ...          ...     ...
# 306089   08:00:00  20     2  2021     Saturday  Winter
# 306090   03:15:00   6     5  2021     Thursday  Spring
# 306091   10:38:00   5     5  2021    Wednesday  Spring
# 306092   01:35:00  13     3  2021     Saturday  Spring
# 306093   04:00:00  18     4  2021       Sunday  Spring
#
# [306094 rows x 29 columns]

# %% [markdown]
# #### Extracting hour from Start Time column

# %%
df1['Start_Date_Time'] = pd.to_datetime(df1['Start_Date_Time'], format='%m/%d/%Y %I:%M:%S %p')
df1['hour'] = df1['Start_Date_Time'].dt.hour

# %%
df1
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Dispatch Date Dispatch Time Start Date Start Time day month  year  \
# 0         08/23/2018      09:52:08 2018-08-23   09:52:00  23     8  2018
# 1         03/30/2018      01:00:55 2018-03-30   01:01:00  30     3  2018
# 2         03/30/2018      01:00:55 2018-03-30   01:01:00  30     3  2018
# 3         06/14/2018      10:26:45 2018-06-14   10:26:00  14     6  2018
# 4         09/03/2018      12:06:54 2018-09-02   11:30:00   2     9  2018
# ...              ...           ...        ...        ...  ..   ...   ...
# 306089    02/21/2021      07:25:28 2021-02-20   08:00:00  20     2  2021
# 306090    05/06/2021      10:54:47 2021-05-06   03:15:00   6     5  2021
# 306091    05/05/2021      10:38:58 2021-05-05   10:38:00   5     5  2021
# 306092    03/13/2021      12:07:14 2021-03-13   01:35:00  13     3  2021
# 306093    04/19/2021      02:17:29 2021-04-18   04:00:00  18     4  2021
#
#         Day_of_Week  Season hour
# 0          Thursday  Summer   21
# 1            Friday  Spring    1
# 2            Friday  Spring    1
# 3          Thursday  Summer   22
# 4            Sunday    Fall   23
# ...             ...     ...  ...
# 306089     Saturday  Winter   20
# 306090     Thursday  Spring    3
# 306091    Wednesday  Spring   22
# 306092     Saturday  Spring   13
# 306093       Sunday  Spring   16
#
# [306094 rows x 30 columns]

# %% [markdown]
# ### Filtered the data From year 2018-2022. This helps reduce clutter and ensures that our analysis is more efficient.Since, We need data from 2018-2022

# %%
filtered_df = df1[(df1['Start Date'].dt.year >= 2018) & (df1['Start Date'].dt.year <= 2022)]

# %%
filtered_df
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Dispatch Date Dispatch Time Start Date Start Time day month  year  \
# 0         08/23/2018      09:52:08 2018-08-23   09:52:00  23     8  2018
# 1         03/30/2018      01:00:55 2018-03-30   01:01:00  30     3  2018
# 2         03/30/2018      01:00:55 2018-03-30   01:01:00  30     3  2018
# 3         06/14/2018      10:26:45 2018-06-14   10:26:00  14     6  2018
# 4         09/03/2018      12:06:54 2018-09-02   11:30:00   2     9  2018
# ...              ...           ...        ...        ...  ..   ...   ...
# 306089    02/21/2021      07:25:28 2021-02-20   08:00:00  20     2  2021
# 306090    05/06/2021      10:54:47 2021-05-06   03:15:00   6     5  2021
# 306091    05/05/2021      10:38:58 2021-05-05   10:38:00   5     5  2021
# 306092    03/13/2021      12:07:14 2021-03-13   01:35:00  13     3  2021
# 306093    04/19/2021      02:17:29 2021-04-18   04:00:00  18     4  2021
#
#         Day_of_Week  Season hour
# 0          Thursday  Summer   21
# 1            Friday  Spring    1
# 2            Friday  Spring    1
# 3          Thursday  Summer   22
# 4            Sunday    Fall   23
# ...             ...     ...  ...
# 306089     Saturday  Winter   20
# 306090     Thursday  Spring    3
# 306091    Wednesday  Spring   22
# 306092     Saturday  Spring   13
# 306093       Sunday  Spring   16
#
# [221565 rows x 30 columns]

# %% [markdown]
# ### Made the copy of filtered_df to use for further analysis

# %%
df = filtered_df.copy()

# %%
df
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Dispatch Date Dispatch Time Start Date Start Time day month  year  \
# 0         08/23/2018      09:52:08 2018-08-23   09:52:00  23     8  2018
# 1         03/30/2018      01:00:55 2018-03-30   01:01:00  30     3  2018
# 2         03/30/2018      01:00:55 2018-03-30   01:01:00  30     3  2018
# 3         06/14/2018      10:26:45 2018-06-14   10:26:00  14     6  2018
# 4         09/03/2018      12:06:54 2018-09-02   11:30:00   2     9  2018
# ...              ...           ...        ...        ...  ..   ...   ...
# 306089    02/21/2021      07:25:28 2021-02-20   08:00:00  20     2  2021
# 306090    05/06/2021      10:54:47 2021-05-06   03:15:00   6     5  2021
# 306091    05/05/2021      10:38:58 2021-05-05   10:38:00   5     5  2021
# 306092    03/13/2021      12:07:14 2021-03-13   01:35:00  13     3  2021
# 306093    04/19/2021      02:17:29 2021-04-18   04:00:00  18     4  2021
#
#         Day_of_Week  Season hour
# 0          Thursday  Summer   21
# 1            Friday  Spring    1
# 2            Friday  Spring    1
# 3          Thursday  Summer   22
# 4            Sunday    Fall   23
# ...             ...     ...  ...
# 306089     Saturday  Winter   20
# 306090     Thursday  Spring    3
# 306091    Wednesday  Spring   22
# 306092     Saturday  Spring   13
# 306093       Sunday  Spring   16
#
# [221565 rows x 30 columns]

# %%
df.to_csv('Final_Data.csv')

# %% [markdown]
# ## Q1. Based on frequency, what are the top 10 crime categories in the dataset?

# %%
#counting the number of crimes
crime_counts = df['Crime Name2'].value_counts().reset_index()

# %%
crime_counts = crime_counts[~crime_counts['Crime Name2'].isin(['All Other Offenses'])]

# %%
#Renaming the columns of crime_counts
crime_counts.columns = ['Crime Category' , 'Frequency']

# %%
crime_counts
# Out:
#                                  Crime Category  Frequency
# 1                      Theft From Motor Vehicle      18877
# 2                                Simple Assault      15798
# 3                      Drug/Narcotic Violations      14794
# 4      Destruction/Damage/Vandalism of Property      13642
# 5                                   Shoplifting      12274
# 6                             All other Larceny       9952
# 7                   Driving Under the Influence       9947
# 8                                Identity Theft       7887
# 9                           Theft from Building       7862
# 10               Burglary/Breaking and Entering       6131
# 11  Theft of Motor Vehicle Parts or Accessories       5449
# 12      False Pretenses/Swindle/Confidence Game       5086
# 13                          Motor Vehicle Theft       5069
# 14                        Liquor Law Violations       4106
# 15   Credit Card/Automatic Teller Machine Fraud       3436
# 16                           Aggravated Assault       3349
# 17                           Disorderly Conduct       3021
# 18                                      Runaway       2552
# 19                    Trespass of Real Property       2550
# 20                                      Robbery       2471
# 21                       Counterfeiting/Forgery       2416
# 22                        Weapon Law Violations       1720
# 23                    Drug Equipment Violations       1190
# 24                                Forcible Rape       1054
# 25                                     Fondling        810
# 26                  Family Offenses, NonViolent        581
# 27                              Forcible Sodomy        486
# 28                               Pocket/picking        481
# 29                            Forcible Fondling        396
# 30                                 Embezzlement        336
# 31                          Extortion/Blackmail        317
# 32                Sexual Assault With An Object        317
# 33                              Purse-snatching        298
# 34                                 Intimidation        277
# 35                                      Unknown        259
# 36                                        Arson        251
# 37                 Pornography/Obscene Material        241
# 38                                   Bad Checks        234
# 39                                   Wire Fraud        217
# 40                                Impersonation        213
# 41                               NOT NIBRS CODE        187
# 42                                   Not Mapped        182
# 43                     Stolen Property Offenses        145
# 44                                 Prostitution        101
# 45         Murder and Nonnegligent Manslaughter         91
# 46                                  Peeping Tom         82
# 47                                  Drunkenness         64
# 48                         Kidnapping/Abduction         56
# 49         From Coin/Operated Machine or Device         41
# 50       Human Trafficking, Commercial Sex Acts         29
# 51                                Statuory Rape         27
# 52         Curfew/Loitering/Vagrancy Violations         19
# 53                         Justifiable Homicide         13
# 54                                Welfare Fraud         11
# 55          Assisting or Promoting Prostitution         11
# 56     Human Trafficking, Involuntary Servitude          2
# 57                       Negligent Manslaughter          1
# 58       Operating/Promoting/Assisting Gambling          1
# 59                                      Bribery          1

# %%
#To identify the top 10 crime categories
top_10_crimes = crime_counts.head(10)

# %%
top_10_crimes
# Out:
#                               Crime Category  Frequency
# 1                   Theft From Motor Vehicle      18877
# 2                             Simple Assault      15798
# 3                   Drug/Narcotic Violations      14794
# 4   Destruction/Damage/Vandalism of Property      13642
# 5                                Shoplifting      12274
# 6                          All other Larceny       9952
# 7                Driving Under the Influence       9947
# 8                             Identity Theft       7887
# 9                        Theft from Building       7862
# 10            Burglary/Breaking and Entering       6131

# %%
plt.figure(figsize=(10, 6))
bars = plt.barh(top_10_crimes['Crime Category'], top_10_crimes['Frequency'], color='lightcoral')
plt.xlabel('Frequency')
plt.ylabel('Crime Category')
plt.title('Top 10 Crime Categories', fontweight='bold')
plt.gca().invert_yaxis()  # To display the highest frequency on top
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2,
             f'{bar.get_width()}',
             va='center', ha='left', fontsize=8 , fontweight='bold');

# %%
top_10_crimes_percentages = (top_10_crimes['Frequency'] / top_10_crimes['Frequency'].sum()) * 100

# %%
top_10_crimes_percentages
# Out:
# 1     16.111604
# 2     13.483664
# 3     12.626745
# 4     11.643508
# 5     10.475914
# 6      8.494077
# 7      8.489809
# 8      6.731590
# 9      6.710252
# 10     5.232836
# Name: Frequency, dtype: float64

# %%
#to label the values in donut chart
##labels = [f"{crime_name} ({count})" for crime_name, count in zip(top_10_Crimes.index, top_10_Crimes.values)]
labels = [f"{count/1000:.1f}K ({percent:.1f}%)" for count, percent in zip(top_10_crimes['Frequency'].values, top_10_crimes_percentages.values)]

# %%
plt.figure(figsize = (12,8), dpi = 200)
plt.title("Top 10 Crimes", fontsize=16, fontweight='bold', color='darkblue', pad=20)
plt.pie(x = top_10_crimes['Frequency'].values, labels = labels , startangle = 140, wedgeprops = dict(width = 0.3))
plt.legend (top_10_crimes['Crime Category'].values, loc = 'center', frameon=False, title='Crime Categories' )
plt.axis('equal');

# %% [markdown]
# #### The graph provides a clear visual representation of the frequency of various crime categories, making it easy to compare them at a glance.
#
# #### All Other Offenses stands out prominently, with a frequency of 54,154 incidents. This suggests that this category includes a diverse range of offenses, making it the most common type of crime in the dataset.
#
# #### In contrast, categories like Theft From Motor Vehicle (18,877) and Simple Assault (15,798) are also significant but not as prevalent as All Other Offenses. These figures indicate that while these crimes are notable, they occur less frequently.
#
# #### On the lower end of the spectrum, we see Identity Theft (7,887) and Theft from Building (7,862), which have the least occurrences in this dataset. This suggests that these types of crimes are less common compared to others.
#
# #### Overall, this data can be invaluable for law enforcement and policymakers. By identifying which crime types are most prevalent, they can better allocate resources and develop effective prevention strategies.

# %% [markdown]
# ## Q2.What trends and changes have occurred in crime rates from 2018 to 2022?

# %%
# Group by 'Crime Name1' and 'Year' and count the occurrences
yearly_counts = df.groupby(['Crime Name1', 'year']).size().reset_index(name='Count')

# %%
yearly_counts = yearly_counts[~yearly_counts['Crime Name1'].isin(['Other', 'Unknown'])]

# %%
yearly_counts
# Out:
#                Crime Name1  year  Count
# 0     Crime Against Person  2018   5130
# 1     Crime Against Person  2019   4946
# 2     Crime Against Person  2020   4423
# 3     Crime Against Person  2021   5069
# 4     Crime Against Person  2022   3240
# 5   Crime Against Property  2018  21650
# 6   Crime Against Property  2019  22026
# 7   Crime Against Property  2020  22945
# 8   Crime Against Property  2021  23086
# 9   Crime Against Property  2022  13473
# 10   Crime Against Society  2018  15839
# 11   Crime Against Society  2019  13048
# 12   Crime Against Society  2020   7127
# 13   Crime Against Society  2021   5446
# 14   Crime Against Society  2022   3785
# 15             Not a Crime  2018    625
# 16             Not a Crime  2019    639
# 17             Not a Crime  2020    514
# 18             Not a Crime  2021    395
# 19             Not a Crime  2022    379

# %%
pivot_df= yearly_counts.pivot(index='year', columns='Crime Name1', values='Count').fillna(0)

# Plotting
pivot_df.plot(kind='bar', figsize=(12, 6))

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Number of Crimes/Offences Recorded')
plt.title('Total Recorded Incidents')
plt.title('Trends in Crime Rates (2018-2022)')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.legend(title='Category of Crime ')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=yearly_counts, x='year', y='Count', hue='Crime Name1', marker='o')

# Adding annotations for each point
for i in range(len(yearly_counts)):
    plt.annotate(yearly_counts['Count'].iloc[i],
                 (yearly_counts['year'].iloc[i], yearly_counts['Count'].iloc[i]),
                 textcoords="offset points",
                 xytext=(0,5),
                 ha='center')

# Adding labels and title
plt.xlabel('year',fontsize=14)
plt.ylabel('Number of Crimes/Offences Recorded', fontsize=14)
plt.title('Line Plot of Crimes Recorded by Year', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Category of Crime', loc='upper right', bbox_to_anchor=(1.25, 1))
plt.grid()
plt.show()

# %% [markdown]
# #### The data indicates a downward trend in most crime categories over the years, particularly in Crime Against Society and Crime Against Person.
# #### The spike in Crime Against Property in 2021 suggests a temporary increase, possibly due to specific events or changes in reporting practices.

# %% [markdown]
# ## Q3. Which are the top 10 districts with the highest crime rates that require greater attention for crime reduction?

# %%
df['City'].value_counts()
pd.set_option('display.max_rows', None)

# %%
df['City'].value_counts()
# Out:
# City
# SILVER SPRING         75973
# GAITHERSBURG          32289
# ROCKVILLE             30788
# GERMANTOWN            21811
# BETHESDA              15496
# MONTGOMERY VILLAGE     6556
# TAKOMA PARK            6025
# POTOMAC                4753
# CHEVY CHASE            4731
# DERWOOD                4139
# KENSINGTON             3577
# OLNEY                  3293
# BURTONSVILLE           2729
# CLARKSBURG             2343
# DAMASCUS               1868
# BOYDS                  1466
# Unknown                 928
# BROOKEVILLE             678
# POOLESVILLE             666
# SANDY SPRING            305
# ASHTON                  276
# DICKERSON               221
# CABIN JOHN              171
# SPENCERVILLE             96
# GLEN ECHO                60
# MOUNT AIRY               46
# BRINKLOW                 44
# LAUREL                   35
# BARNESVILLE              33
# BEALLSVILLE              28
# MT AIRY                  21
# BELTSVILLE               18
# WASHINGTON               18
# GARRETT PARK             16
# HYATTSVILLE              13
# WASHINGTON GROVE          9
# HIGHLAND                  8
# WHEATON                   6
# WOODBINE                  4
# BETHEDA                   2
# ROCKVILLLE                2
# HAGERSTOWN                1
# WEST FRIENDSHIP           1
# VIENNA                    1
# LANHAM                    1
# MCLEAN                    1
# TACOMA PARK               1
# ADELPHI                   1
# BOWIE                     1
# 0                         1
# ALEXANDRIA                1
# ROCKVIILE                 1
# MOUNT RAINIER             1
# RIVERDALE                 1
# GAIHTERSBURG              1
# CAPITOL HEIGHTS           1
# NORTH BETHESDA            1
# CLAEKSBURG                1
# NORTH POTOMAC             1
# COLLEGE PARK              1
# FRIENDSHIP HEIGHTS        1
# FALLS CHURCH              1
# GAITHERSBUG               1
# SILVERS SPRING            1
# GREENBELT                 1
# Name: count, dtype: int64

# %%
df['Crime Name2'].value_counts()
pd.set_option('display.max_rows', None)
print(df['Crime Name2'].value_counts())
# Out:
# Crime Name2
# All Other Offenses                             54154
# Theft From Motor Vehicle                       18877
# Simple Assault                                 15798
# Drug/Narcotic Violations                       14794
# Destruction/Damage/Vandalism of Property       13642
# Shoplifting                                    12274
# All other Larceny                               9952
# Driving Under the Influence                     9947
# Identity Theft                                  7887
# Theft from Building                             7862
# Burglary/Breaking and Entering                  6131
# Theft of Motor Vehicle Parts or Accessories     5449
# False Pretenses/Swindle/Confidence Game         5086
# Motor Vehicle Theft                             5069
# Liquor Law Violations                           4106
# Credit Card/Automatic Teller Machine Fraud      3436
# Aggravated Assault                              3349
# Disorderly Conduct                              3021
# Runaway                                         2552
# Trespass of Real Property                       2550
# Robbery                                         2471
# Counterfeiting/Forgery                          2416
# Weapon Law Violations                           1720
# Drug Equipment Violations                       1190
# Forcible Rape                                   1054
# Fondling                                         810
# Family Offenses, NonViolent                      581
# Forcible Sodomy                                  486
# Pocket/picking                                   481
# Forcible Fondling                                396
# Embezzlement                                     336
# Extortion/Blackmail                              317
# Sexual Assault With An Object                    317
# Purse-snatching                                  298
# Intimidation                                     277
# Unknown                                          259
# Arson                                            251
# Pornography/Obscene Material                     241
# Bad Checks                                       234
# Wire Fraud                                       217
# Impersonation                                    213
# NOT NIBRS CODE                                   187
# Not Mapped                                       182
# Stolen Property Offenses                         145
# Prostitution                                     101
# Murder and Nonnegligent Manslaughter              91
# Peeping Tom                                       82
# Drunkenness                                       64
# Kidnapping/Abduction                              56
# From Coin/Operated Machine or Device              41
# Human Trafficking, Commercial Sex Acts            29
# Statuory Rape                                     27
# Curfew/Loitering/Vagrancy Violations              19
# Justifiable Homicide                              13
# Welfare Fraud                                     11
# Assisting or Promoting Prostitution               11
# Human Trafficking, Involuntary Servitude           2
# Negligent Manslaughter                             1
# Operating/Promoting/Assisting Gambling             1
# Bribery                                            1
# Name: count, dtype: int64

# %%
#since we are checking the Top 10 cities with the highest crime rate.

top_cities=df['City'].value_counts().head(10)

# %%
top_cities_df = top_cities.reset_index()
top_cities_df.columns = ['City', 'Number of Crimes']
top_cities_df
# Out:
#                  City  Number of Crimes
# 0       SILVER SPRING             75973
# 1        GAITHERSBURG             32289
# 2           ROCKVILLE             30788
# 3          GERMANTOWN             21811
# 4            BETHESDA             15496
# 5  MONTGOMERY VILLAGE              6556
# 6         TAKOMA PARK              6025
# 7             POTOMAC              4753
# 8         CHEVY CHASE              4731
# 9             DERWOOD              4139

# %%
heatmap_data = top_cities_df.pivot(index = "City", columns ="Number of Crimes", values = "Number of Crimes")

# Create the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="YlGnBu", linewidths=.5)

# Add title and labels
plt.title('Top 10 Cities with the highest Crime Rate', fontsize=16, pad=30)
plt.xlabel('Number of Crimes', fontsize=20)
plt.ylabel('City', fontsize=20)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='City', y='Number of Crimes', data=top_cities_df, palette='viridis')

for index, row in top_cities_df.iterrows():
    barplot.text(row.name, row['Number of Crimes'], round(row['Number of Crimes'], 2), color='black', ha="center")

plt.xlabel('City')
plt.ylabel('Number of Crimes')
plt.title('Top 10 Cities with the highest Crime Rate')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### The data reveals significant variations in crime rates across different cities. Silver Spring has the highest number of reported crimes at 75,973, indicating a potential need for increased safety measures or community programs. Following are Gaithersburg and Rockville, with 32,289 and 30,788 crimes, respectively, suggesting they also face notable crime challenges. In contrast, cities like Montgomery Village (6,556) and Takoma Park (6,025) report much lower crime counts, which may reflect safer environments.
# #### This dataset provides valuable insights into crime trends across different cities, highlighting areas that may require more attention and resources to enhance public safety.

# %% [markdown]
# ## Q4.What differences exist in crime patterns between weekdays and weekends

# %%
print(df.columns)
# Out:
# Index(['Incident ID', 'Offence Code', 'CR Number', 'Dispatch Date / Time',
#        'NIBRS Code', 'Victims', 'Crime Name1', 'Crime Name2', 'Crime Name3',
#        'Police District Name', 'Block Address', 'City', 'State', 'Place',
#        'Street Name', 'Street Type', 'Start_Date_Time', 'Latitude',
#        'Longitude', 'Police District Number', 'Dispatch Date', 'Dispatch Time',
#        'Start Date', 'Start Time', 'day', 'month', 'year', 'Day_of_Week',
#        'Season', 'hour'],
#       dtype='object')

# %%
crime_counts1 = df['Day_of_Week'].value_counts()
crime_counts1.columns = ['Day_of_Week' , 'Crime counts']
crime_counts1
# Out:
# Day_of_Week
# Friday       34473
# Wednesday    33146
# Thursday     32825
# Tuesday      32737
# Monday       31454
# Saturday     29479
# Sunday       27451
# Name: count, dtype: int64

# %%
ordered_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
crime_counts1 = crime_counts1.reindex(ordered_days)

# %%
crime_counts1 = crime_counts1.reset_index()
crime_counts1.columns = ['Day_of_Week', 'Counts']

# %%
crime_counts1
# Out:
#   Day_of_Week  Counts
# 0      Monday   31454
# 1     Tuesday   32737
# 2   Wednesday   33146
# 3    Thursday   32825
# 4      Friday   34473
# 5    Saturday   29479
# 6      Sunday   27451

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='Counts', y='Day_of_Week', data=crime_counts1, palette='coolwarm')

for index, value in enumerate(crime_counts1['Counts']):
    plt.text(value, index, str(value))


plt.title('Crime Counts on Each Day of the Week')
plt.xlabel('Number of Crimes')
plt.ylabel('Day of the Week')
plt.tight_layout();

# %%
plt.figure(figsize=(12, 6))

# Create a line plot
plt.plot(crime_counts1['Day_of_Week'], crime_counts1['Counts'], marker='o', linestyle='-', color='b')

# Set plot title and labels
plt.title('Crime Counts on Each Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Crimes')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### the visualizations effectively communicate the trend and distribution of crime counts each day of the week,particularly emphasizing the significance of Fridays.
# ####  The increase in crime on Fridays can be linked to heightened social activities, alcohol consumption, and late-night outings, which create opportunities for various offenses.
